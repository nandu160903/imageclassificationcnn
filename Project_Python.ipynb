# %%
pip install tensorflow numpy matplotlib scikit-learn seaborn
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Set random seeds for reproducibility
tf.random.set_seed(42)
np.random.seed(42)

# CIFAR-10 class names
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# Load and preprocess CIFAR-10 dataset
print("Loading CIFAR-10 dataset...")
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# Normalize pixel values to [0, 1]
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Convert labels to categorical
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

print(f"Training data shape: {x_train.shape}")
print(f"Test data shape: {x_test.shape}")
print(f"Training labels shape: {y_train.shape}")
print(f"Test labels shape: {y_test.shape}")

# Data augmentation
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
])

# Build CNN model
def create_cnn_model():
    model = keras.Sequential([
        # Data augmentation layer
        data_augmentation,

        # First convolutional block
        layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
        layers.BatchNormalization(),
        layers.Conv2D(32, (3, 3), activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # Second convolutional block
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # # Third convolutional block (Removed to fix dimension error)
        # layers.Conv2D(128, (3, 3), activation='relu'),
        # layers.BatchNormalization(),
        # layers.Conv2D(128, (3, 3), activation='relu'),
        # layers.MaxPooling2D((2, 2)), # This was causing the error
        # layers.Dropout(0.25),

        # Dense layers
        layers.Flatten(),
        layers.Dense(512, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(10, activation='softmax')
    ])

    return model

# Create and compile model
model = create_cnn_model()
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Display model architecture
print("\nModel Architecture:")
model.summary()

# Callbacks for training
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=5,
        min_lr=0.0001
    ),
    keras.callbacks.ModelCheckpoint(
        'best_cifar10_model.h5',
        monitor='val_accuracy',
        save_best_only=True
    )
]

# Train the model
print("\nStarting training...")
history = model.fit(
    x_train, y_train,
    batch_size=32,
    epochs=50,
    validation_data=(x_test, y_test),
    callbacks=callbacks,
    verbose=1
)

# Evaluate the model
print("\nEvaluating model...")
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"Test accuracy: {test_accuracy:.4f}")
print(f"Test loss: {test_loss:.4f}")

# Make predictions
predictions = model.predict(x_test)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(y_test, axis=1)

# Print classification report
print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_names))

# Plot training history
def plot_training_history(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

    # Plot training & validation accuracy
    ax1.plot(history.history['accuracy'], label='Training Accuracy')
    ax1.plot(history.history['val_accuracy'], label='Validation Accuracy')
    ax1.set_title('Model Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend()
    ax1.grid(True)

    # Plot training & validation loss
    ax2.plot(history.history['loss'], label='Training Loss')
    ax2.plot(history.history['val_loss'], label='Validation Loss')
    ax2.set_title('Model Loss')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend()
    ax2.grid(True)

    plt.tight_layout()
    plt.show()

plot_training_history(history)

# Plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

plot_confusion_matrix(true_classes, predicted_classes, class_names)

# Display some sample predictions
def display_predictions(x_test, y_test, predictions, class_names, num_samples=10):
    indices = np.random.choice(len(x_test), num_samples, replace=False)

    fig, axes = plt.subplots(2, 5, figsize=(15, 6))
    axes = axes.ravel()

    for i, idx in enumerate(indices):
        axes[i].imshow(x_test[idx])
        axes[i].set_title(f'True: {class_names[np.argmax(y_test[idx])]}\n'
                         f'Pred: {class_names[np.argmax(predictions[idx])]}')
        axes[i].axis('off')

    plt.tight_layout()
    plt.show()

display_predictions(x_test, y_test, predictions, class_names)

# Function to predict on new images
def predict_image(model, image, class_names):
    """
    Predict class for a single image

    Args:
        model: trained model
        image: preprocessed image (32x32x3)
        class_names: list of class names

    Returns:
        predicted class and confidence
    """
    if image.shape != (32, 32, 3):
        raise ValueError("Image must be 32x32x3")

    # Normalize if needed
    if image.max() > 1:
        image = image / 255.0

    # Add batch dimension
    image = np.expand_dims(image, axis=0)

    # Make prediction
    prediction = model.predict(image)
    predicted_class = np.argmax(prediction)
    confidence = np.max(prediction)

    return class_names[predicted_class], confidence

# Save the model
model.save('cifar10_cnn_model.h5')
print("\nModel saved as 'cifar10_cnn_model.h5'")

print("\nTraining complete!")
print(f"Final test accuracy: {test_accuracy:.4f}")
# Out:
# Loading CIFAR-10 dataset...
# Training data shape: (50000, 32, 32, 3)
# Test data shape: (10000, 32, 32, 3)
# Training labels shape: (50000, 10)
# Test labels shape: (10000, 10)
#
# Model Architecture:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_4 (Sequential)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Starting training...
# Epoch 1/50
# 1562/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.2778 - loss: 2.2421
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 180s 86ms/step - accuracy: 0.2779 - loss: 2.2416 - val_accuracy: 0.4107 - val_loss: 1.6699 - learning_rate: 0.0010
# Epoch 2/50
# 1562/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.4491 - loss: 1.5148
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 138s 83ms/step - accuracy: 0.4491 - loss: 1.5148 - val_accuracy: 0.4157 - val_loss: 1.8110 - learning_rate: 0.0010
# Epoch 3/50
# 1562/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5087 - loss: 1.3749
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 140s 82ms/step - accuracy: 0.5087 - loss: 1.3749 - val_accuracy: 0.4923 - val_loss: 1.4513 - learning_rate: 0.0010
# Epoch 4/50
# 1562/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5449 - loss: 1.2953
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 147s 85ms/step - accuracy: 0.5449 - loss: 1.2952 - val_accuracy: 0.6134 - val_loss: 1.0753 - learning_rate: 0.0010
# Epoch 5/50
# 1562/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5750 - loss: 1.2188
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 135s 87ms/step - accuracy: 0.5750 - loss: 1.2188 - val_accuracy: 0.6190 - val_loss: 1.0921 - learning_rate: 0.0010
# Epoch 6/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 144s 88ms/step - accuracy: 0.5920 - loss: 1.1746 - val_accuracy: 0.5798 - val_loss: 1.2375 - learning_rate: 0.0010
# Epoch 7/50
# 1562/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6026 - loss: 1.1431
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 141s 87ms/step - accuracy: 0.6026 - loss: 1.1431 - val_accuracy: 0.6347 - val_loss: 1.1147 - learning_rate: 0.0010
# Epoch 8/50
# 1562/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6151 - loss: 1.1070
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 130s 80ms/step - accuracy: 0.6151 - loss: 1.1070 - val_accuracy: 0.6574 - val_loss: 0.9791 - learning_rate: 0.0010
# Epoch 9/50
# 1562/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6336 - loss: 1.0645
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 138s 88ms/step - accuracy: 0.6336 - loss: 1.0645 - val_accuracy: 0.6665 - val_loss: 0.9634 - learning_rate: 0.0010
# Epoch 10/50
# 1562/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6397 - loss: 1.0488
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 133s 83ms/step - accuracy: 0.6397 - loss: 1.0488 - val_accuracy: 0.6859 - val_loss: 0.8996 - learning_rate: 0.0010
# Epoch 11/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 138s 80ms/step - accuracy: 0.6439 - loss: 1.0346 - val_accuracy: 0.6469 - val_loss: 1.0256 - learning_rate: 0.0010
# Epoch 12/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 143s 81ms/step - accuracy: 0.6500 - loss: 1.0258 - val_accuracy: 0.6798 - val_loss: 0.9343 - learning_rate: 0.0010
# Epoch 13/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 125s 80ms/step - accuracy: 0.6542 - loss: 1.0068 - val_accuracy: 0.6491 - val_loss: 1.0369 - learning_rate: 0.0010
# Epoch 14/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 130s 83ms/step - accuracy: 0.6583 - loss: 0.9901 - val_accuracy: 0.6723 - val_loss: 0.9908 - learning_rate: 0.0010
# Epoch 15/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 138s 81ms/step - accuracy: 0.6687 - loss: 0.9660 - val_accuracy: 0.6695 - val_loss: 0.9537 - learning_rate: 0.0010
# Epoch 16/50
# 1562/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6864 - loss: 0.9087
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 142s 81ms/step - accuracy: 0.6864 - loss: 0.9087 - val_accuracy: 0.7227 - val_loss: 0.8022 - learning_rate: 2.0000e-04
# Epoch 17/50
# 1562/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6943 - loss: 0.8932
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 145s 83ms/step - accuracy: 0.6943 - loss: 0.8931 - val_accuracy: 0.7352 - val_loss: 0.7716 - learning_rate: 2.0000e-04
# Epoch 18/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7008 - loss: 0.8704
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 142s 83ms/step - accuracy: 0.7009 - loss: 0.8704 - val_accuracy: 0.7437 - val_loss: 0.7465 - learning_rate: 2.0000e-04
# Epoch 19/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 129s 83ms/step - accuracy: 0.7058 - loss: 0.8601 - val_accuracy: 0.7272 - val_loss: 0.7892 - learning_rate: 2.0000e-04
# Epoch 20/50
# 1562/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7074 - loss: 0.8496
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 147s 86ms/step - accuracy: 0.7074 - loss: 0.8496 - val_accuracy: 0.7465 - val_loss: 0.7351 - learning_rate: 2.0000e-04
# Epoch 21/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 147s 89ms/step - accuracy: 0.7075 - loss: 0.8517 - val_accuracy: 0.7449 - val_loss: 0.7277 - learning_rate: 2.0000e-04
# Epoch 22/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 147s 93ms/step - accuracy: 0.7078 - loss: 0.8493 - val_accuracy: 0.7435 - val_loss: 0.7316 - learning_rate: 2.0000e-04
# Epoch 23/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 132s 84ms/step - accuracy: 0.7104 - loss: 0.8452 - val_accuracy: 0.7413 - val_loss: 0.7394 - learning_rate: 2.0000e-04
# Epoch 24/50
# 1562/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7128 - loss: 0.8385
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 136s 80ms/step - accuracy: 0.7129 - loss: 0.8385 - val_accuracy: 0.7564 - val_loss: 0.7043 - learning_rate: 2.0000e-04
# Epoch 25/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 148s 84ms/step - accuracy: 0.7162 - loss: 0.8327 - val_accuracy: 0.7419 - val_loss: 0.7408 - learning_rate: 2.0000e-04
# Epoch 26/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 139s 82ms/step - accuracy: 0.7132 - loss: 0.8295 - val_accuracy: 0.7378 - val_loss: 0.7621 - learning_rate: 2.0000e-04
# Epoch 27/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 143s 83ms/step - accuracy: 0.7165 - loss: 0.8216 - val_accuracy: 0.7508 - val_loss: 0.7130 - learning_rate: 2.0000e-04
# Epoch 28/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 140s 82ms/step - accuracy: 0.7204 - loss: 0.8179 - val_accuracy: 0.7408 - val_loss: 0.7448 - learning_rate: 2.0000e-04
# Epoch 29/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 148s 86ms/step - accuracy: 0.7226 - loss: 0.8121 - val_accuracy: 0.7560 - val_loss: 0.7035 - learning_rate: 2.0000e-04
# Epoch 30/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 130s 83ms/step - accuracy: 0.7228 - loss: 0.8051 - val_accuracy: 0.7483 - val_loss: 0.7152 - learning_rate: 2.0000e-04
# Epoch 31/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 131s 83ms/step - accuracy: 0.7200 - loss: 0.8108 - val_accuracy: 0.7527 - val_loss: 0.7115 - learning_rate: 2.0000e-04
# Epoch 32/50
# 1562/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7222 - loss: 0.8163
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 145s 86ms/step - accuracy: 0.7222 - loss: 0.8163 - val_accuracy: 0.7630 - val_loss: 0.6906 - learning_rate: 2.0000e-04
# Epoch 33/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 145s 88ms/step - accuracy: 0.7220 - loss: 0.8068 - val_accuracy: 0.7527 - val_loss: 0.7107 - learning_rate: 2.0000e-04
# Epoch 34/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 143s 89ms/step - accuracy: 0.7240 - loss: 0.8008 - val_accuracy: 0.7594 - val_loss: 0.6953 - learning_rate: 2.0000e-04
# Epoch 35/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 133s 83ms/step - accuracy: 0.7240 - loss: 0.8021 - val_accuracy: 0.7551 - val_loss: 0.7119 - learning_rate: 2.0000e-04
# Epoch 36/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 152s 89ms/step - accuracy: 0.7233 - loss: 0.7990 - val_accuracy: 0.7541 - val_loss: 0.7078 - learning_rate: 2.0000e-04
# Epoch 37/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7243 - loss: 0.7990
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 144s 92ms/step - accuracy: 0.7243 - loss: 0.7990 - val_accuracy: 0.7646 - val_loss: 0.6800 - learning_rate: 2.0000e-04
# Epoch 38/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 144s 92ms/step - accuracy: 0.7270 - loss: 0.7938 - val_accuracy: 0.7641 - val_loss: 0.6892 - learning_rate: 2.0000e-04
# Epoch 39/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 201s 91ms/step - accuracy: 0.7294 - loss: 0.7783 - val_accuracy: 0.7588 - val_loss: 0.7069 - learning_rate: 2.0000e-04
# Epoch 40/50
# 1562/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7326 - loss: 0.7802
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 144s 92ms/step - accuracy: 0.7326 - loss: 0.7802 - val_accuracy: 0.7667 - val_loss: 0.6744 - learning_rate: 2.0000e-04
# Epoch 41/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 197s 89ms/step - accuracy: 0.7312 - loss: 0.7851 - val_accuracy: 0.7503 - val_loss: 0.7218 - learning_rate: 2.0000e-04
# Epoch 42/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7310 - loss: 0.7786
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 144s 92ms/step - accuracy: 0.7310 - loss: 0.7786 - val_accuracy: 0.7716 - val_loss: 0.6703 - learning_rate: 2.0000e-04
# Epoch 43/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 202s 92ms/step - accuracy: 0.7330 - loss: 0.7733 - val_accuracy: 0.7671 - val_loss: 0.6783 - learning_rate: 2.0000e-04
# Epoch 44/50
# 1562/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7313 - loss: 0.7766
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 142s 91ms/step - accuracy: 0.7313 - loss: 0.7766 - val_accuracy: 0.7723 - val_loss: 0.6645 - learning_rate: 2.0000e-04
# Epoch 45/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 147s 94ms/step - accuracy: 0.7324 - loss: 0.7764 - val_accuracy: 0.7619 - val_loss: 0.6871 - learning_rate: 2.0000e-04
# Epoch 46/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 147s 94ms/step - accuracy: 0.7322 - loss: 0.7688 - val_accuracy: 0.7654 - val_loss: 0.6892 - learning_rate: 2.0000e-04
# Epoch 47/50
# 1562/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7341 - loss: 0.7744
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 147s 94ms/step - accuracy: 0.7341 - loss: 0.7744 - val_accuracy: 0.7755 - val_loss: 0.6549 - learning_rate: 2.0000e-04
# Epoch 48/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 201s 94ms/step - accuracy: 0.7377 - loss: 0.7702 - val_accuracy: 0.7749 - val_loss: 0.6526 - learning_rate: 2.0000e-04
# Epoch 49/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 198s 91ms/step - accuracy: 0.7379 - loss: 0.7641 - val_accuracy: 0.7697 - val_loss: 0.6630 - learning_rate: 2.0000e-04
# Epoch 50/50
# 1562/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7366 - loss: 0.7725
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 142s 91ms/step - accuracy: 0.7366 - loss: 0.7725 - val_accuracy: 0.7775 - val_loss: 0.6472 - learning_rate: 2.0000e-04
#
# Evaluating model...
# Test accuracy: 0.7775
# Test loss: 0.6472
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     airplane       0.81      0.81      0.81      1000
#   automobile       0.90      0.90      0.90      1000
#         bird       0.78      0.62      0.69      1000
#          cat       0.72      0.50      0.59      1000
#         deer       0.72      0.75      0.73      1000
#          dog       0.78      0.65      0.71      1000
#         frog       0.67      0.92      0.78      1000
#        horse       0.83      0.83      0.83      1000
#         ship       0.85      0.89      0.87      1000
#        truck       0.75      0.91      0.82      1000
#
#     accuracy                           0.78     10000
#    macro avg       0.78      0.78      0.77     10000
# weighted avg       0.78      0.78      0.77     10000
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved as 'cifar10_cnn_model.h5'
#
# Training complete!
# Final test accuracy: 0.7775
